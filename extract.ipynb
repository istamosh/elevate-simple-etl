# %%
import requests
from bs4 import BeautifulSoup as bs
import time
import json
import os

# %%
# list url pagination yang akan di-scrape

def build_urls():
    return ['https://fashion-studio.dicoding.dev/'] + [f'https://fashion-studio.dicoding.dev/page{i}' for i in range(2, 51)]
urls = build_urls()
print(urls)
# Out:
# ['https://fashion-studio.dicoding.dev/', 'https://fashion-studio.dicoding.dev/page2', 'https://fashion-studio.dicoding.dev/page3', 'https://fashion-studio.dicoding.dev/page4', 'https://fashion-studio.dicoding.dev/page5', 'https://fashion-studio.dicoding.dev/page6', 'https://fashion-studio.dicoding.dev/page7', 'https://fashion-studio.dicoding.dev/page8', 'https://fashion-studio.dicoding.dev/page9', 'https://fashion-studio.dicoding.dev/page10', 'https://fashion-studio.dicoding.dev/page11', 'https://fashion-studio.dicoding.dev/page12', 'https://fashion-studio.dicoding.dev/page13', 'https://fashion-studio.dicoding.dev/page14', 'https://fashion-studio.dicoding.dev/page15', 'https://fashion-studio.dicoding.dev/page16', 'https://fashion-studio.dicoding.dev/page17', 'https://fashion-studio.dicoding.dev/page18', 'https://fashion-studio.dicoding.dev/page19', 'https://fashion-studio.dicoding.dev/page20', 'https://fashion-studio.dicoding.dev/page21', 'https://fashion-studio.dicoding.dev/page22', 'https://fashion-studio.dicoding.dev/page23', 'https://fashion-studio.dicoding.dev/page24', 'https://fashion-studio.dicoding.dev/page25', 'https://fashion-studio.dicoding.dev/page26', 'https://fashion-studio.dicoding.dev/page27', 'https://fashion-studio.dicoding.dev/page28', 'https://fashion-studio.dicoding.dev/page29', 'https://fashion-studio.dicoding.dev/page30', 'https://fashion-studio.dicoding.dev/page31', 'https://fashion-studio.dicoding.dev/page32', 'https://fashion-studio.dicoding.dev/page33', 'https://fashion-studio.dicoding.dev/page34', 'https://fashion-studio.dicoding.dev/page35', 'https://fashion-studio.dicoding.dev/page36', 'https://fashion-studio.dicoding.dev/page37', 'https://fashion-studio.dicoding.dev/page38', 'https://fashion-studio.dicoding.dev/page39', 'https://fashion-studio.dicoding.dev/page40', 'https://fashion-studio.dicoding.dev/page41', 'https://fashion-studio.dicoding.dev/page42', 'https://fashion-studio.dicoding.dev/page43', 'https://fashion-studio.dicoding.dev/page44', 'https://fashion-studio.dicoding.dev/page45', 'https://fashion-studio.dicoding.dev/page46', 'https://fashion-studio.dicoding.dev/page47', 'https://fashion-studio.dicoding.dev/page48', 'https://fashion-studio.dicoding.dev/page49', 'https://fashion-studio.dicoding.dev/page50']

# %%
def parse_product_card(item):
    title = item.find(class_="product-title").get_text(strip=True)
    price = item.find(class_="price").get_text(strip=True)

    ps = item.find_all("p")
    rating = ps[0].get_text(strip=True)
    color = ps[1].get_text(strip=True)
    size = ps[2].get_text(strip=True)
    gender = ps[3].get_text(strip=True)

    return {
        "title": title,
        "price": price,
        "rating": rating,
        "color": color,
        "size": size,
        "gender": gender,
    }

def parse_page(html):
    soup = bs(html, "html.parser")
    items = soup.find_all(class_="product-details")
    return [parse_product_card(item) for item in items]

FILE = "extracted_data.json"

# cek apakah file sudah ada, jika ada load data dari file, jika tidak scrape data dari web hanya sekali dan simpan ke file
if os.path.exists(FILE):
    with open(FILE, "r", encoding="utf-8") as f:
        data = json.load(f)
    print(f'File {FILE} ditemukan, data berhasil dimuat dari file.')
else:
    # siapkan list untuk menampung data
    data = []

    for url in urls:
        r = requests.get(url, timeout=10)   # request ke setiap url
        r.raise_for_status()  # pastikan request berhasil

        products = parse_page(r.text)
        data.extend(products)

        print(f'Sukses scrape {url}')
        time.sleep(2)  # delay 2 detik untuk menghindari rate limit

    # simpan data ke file JSON
    with open("extracted_data.json", "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2, ensure_ascii=False)
# Out:
# Sukses scrape https://fashion-studio.dicoding.dev/
# Sukses scrape https://fashion-studio.dicoding.dev/page2
# Sukses scrape https://fashion-studio.dicoding.dev/page3
# Sukses scrape https://fashion-studio.dicoding.dev/page4
# Sukses scrape https://fashion-studio.dicoding.dev/page5
# Sukses scrape https://fashion-studio.dicoding.dev/page6
# Sukses scrape https://fashion-studio.dicoding.dev/page7
# Sukses scrape https://fashion-studio.dicoding.dev/page8
# Sukses scrape https://fashion-studio.dicoding.dev/page9
# Sukses scrape https://fashion-studio.dicoding.dev/page10
# Sukses scrape https://fashion-studio.dicoding.dev/page11
# Sukses scrape https://fashion-studio.dicoding.dev/page12
# Sukses scrape https://fashion-studio.dicoding.dev/page13
# Sukses scrape https://fashion-studio.dicoding.dev/page14
# Sukses scrape https://fashion-studio.dicoding.dev/page15
# Sukses scrape https://fashion-studio.dicoding.dev/page16
# Sukses scrape https://fashion-studio.dicoding.dev/page17
# Sukses scrape https://fashion-studio.dicoding.dev/page18
# Sukses scrape https://fashion-studio.dicoding.dev/page19
# Sukses scrape https://fashion-studio.dicoding.dev/page20
# Sukses scrape https://fashion-studio.dicoding.dev/page21
# Sukses scrape https://fashion-studio.dicoding.dev/page22
# Sukses scrape https://fashion-studio.dicoding.dev/page23
# Sukses scrape https://fashion-studio.dicoding.dev/page24
# Sukses scrape https://fashion-studio.dicoding.dev/page25
# Sukses scrape https://fashion-studio.dicoding.dev/page26
# Sukses scrape https://fashion-studio.dicoding.dev/page27
# Sukses scrape https://fashion-studio.dicoding.dev/page28
# Sukses scrape https://fashion-studio.dicoding.dev/page29
# Sukses scrape https://fashion-studio.dicoding.dev/page30
# Sukses scrape https://fashion-studio.dicoding.dev/page31
# Sukses scrape https://fashion-studio.dicoding.dev/page32
# Sukses scrape https://fashion-studio.dicoding.dev/page33
# Sukses scrape https://fashion-studio.dicoding.dev/page34
# Sukses scrape https://fashion-studio.dicoding.dev/page35
# Sukses scrape https://fashion-studio.dicoding.dev/page36
# Sukses scrape https://fashion-studio.dicoding.dev/page37
# Sukses scrape https://fashion-studio.dicoding.dev/page38
# Sukses scrape https://fashion-studio.dicoding.dev/page39
# Sukses scrape https://fashion-studio.dicoding.dev/page40
# Sukses scrape https://fashion-studio.dicoding.dev/page41
# Sukses scrape https://fashion-studio.dicoding.dev/page42
# Sukses scrape https://fashion-studio.dicoding.dev/page43
# Sukses scrape https://fashion-studio.dicoding.dev/page44
# Sukses scrape https://fashion-studio.dicoding.dev/page45
# Sukses scrape https://fashion-studio.dicoding.dev/page46
# Sukses scrape https://fashion-studio.dicoding.dev/page47
# Sukses scrape https://fashion-studio.dicoding.dev/page48
# Sukses scrape https://fashion-studio.dicoding.dev/page49
# Sukses scrape https://fashion-studio.dicoding.dev/page50

# %%
# tampilkan 3 data pertama
print(json.dumps(data[:3], indent=2))
# Out:
# [
#   {
#     "title": "Unknown Product",
#     "price": "$100.00",
#     "rating": "Rating: \u2b50 Invalid Rating / 5",
#     "color": "5 Colors",
#     "size": "Size: M",
#     "gender": "Gender: Men"
#   },
#   {
#     "title": "T-shirt 2",
#     "price": "$102.15",
#     "rating": "Rating: \u2b50 3.9 / 5",
#     "color": "3 Colors",
#     "size": "Size: M",
#     "gender": "Gender: Women"
#   },
#   {
#     "title": "Hoodie 3",
#     "price": "$496.88",
#     "rating": "Rating: \u2b50 4.8 / 5",
#     "color": "3 Colors",
#     "size": "Size: L",
#     "gender": "Gender: Unisex"
#   }
# ]

# %%
# tampilkan 3 data terakhir
print(json.dumps(data[-3:], indent=2))
# Out:
# [
#   {
#     "title": "T-shirt 998",
#     "price": "$56.75",
#     "rating": "Rating: \u2b50 4.2 / 5",
#     "color": "3 Colors",
#     "size": "Size: L",
#     "gender": "Gender: Women"
#   },
#   {
#     "title": "Hoodie 999",
#     "price": "$533.39",
#     "rating": "Rating: \u2b50 4.8 / 5",
#     "color": "3 Colors",
#     "size": "Size: XL",
#     "gender": "Gender: Unisex"
#   },
#   {
#     "title": "Pants 1000",
#     "price": "$183.64",
#     "rating": "Rating: \u2b50 4.7 / 5",
#     "color": "3 Colors",
#     "size": "Size: XXL",
#     "gender": "Gender: Men"
#   }
# ]
